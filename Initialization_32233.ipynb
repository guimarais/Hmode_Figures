# %%
import matplotlib.pyplot as plt
import numpy as np
#
plt.style.use('helvet2')

# %%
i102 = np.loadtxt('SupportFiles/pfh_32233_22313-22315.R102',skiprows=1)
i106 = np.loadtxt('SupportFiles/pfh_32233_22313-22315.R104',skiprows=1)
i104 = np.loadtxt('SupportFiles/pfh_32233_22313-22315.R106',skiprows=1)
init = [i102,i104,i106]
labl = ['R=1.02m','R=1.04m','R=1.06m']

# %%
plt.figure(dpi=200)

for data, label in zip(init,labl):
    plt.plot(data[:,0],data[:,1],label=label)
    
plt.xlabel('R [m]')
plt.legend()
plt.show()
