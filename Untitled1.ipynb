# %% [markdown]
# # Tovaritch's first Notebook

# %%
import dd
import matplotlib.pyplot as plt

# %%
dcn = dd.shotfile('DCN', 33268)
h1 = dcn('H-1')

# %%
plt.plot(h1.time, h1.data, label='H-1')
plt.legend()
plt.show()
