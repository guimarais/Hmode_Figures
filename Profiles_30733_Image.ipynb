# %%
import numpy as np
import matplotlib.pyplot as plt
#
plt.style.use('helvet2')

# %%
fig, ax = plt.subplots(figsize=(6,3),nrows=1,ncols=2,dpi=200, sharey=True)

alphaval = 0.2

for timeind in range(5):
    for diagind in range(2):
        a = np.loadtxt('./SupportFiles/rhoprof_'+str(timeind)+'_'+str(diagind+2)+'.30733')
        ax[diagind].plot(a[:,0],a[:,1])
        
plt.tight_layout()
plt.show()
